# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Import" data-toc-modified-id="Import-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Import</a></span></li><li><span><a href="#Functions" data-toc-modified-id="Functions-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Functions</a></span></li><li><span><a href="#Main" data-toc-modified-id="Main-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Main</a></span></li></ul></div>

# %% [markdown]
# # Import

# %%
# !pip install phate scprep umap-learn tasklogger magic-impute louvain seaborn
# !pip install git+https://github.com/jacoblevine/phenograph.git
# !pip install jupyter_contrib_nbextensions

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import sklearn
import sklearn.cluster
import sklearn.manifold

import scprep
import os
import tasklogger
import phate
import umap

import graphtools as gt
import magic
import phenograph
import louvain

from sklearn.decomposition import PCA
# Out:
# c:\users\stéphane\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:20: DeprecationWarning: This package has been superseded by the `leidenalg` package and will no longer be maintained. Please upgrade to the `leidenalg` package.

# %% [markdown]
# # Functions

# %% [markdown]
# # Main

# %%
data = scprep.io.load_csv("../data/moein_data/moein.data.csv", cell_axis = "column")
metadata = scprep.io.load_csv("../data/moein_data/moein.meta_data.csv")
# Out:
# c:\users\stéphane\appdata\local\programs\python\python37\lib\site-packages\scprep\sanitize.py:53: RuntimeWarning: Data is not numeric. Many scprep functions will not work.
#   RuntimeWarning,

# %%
data_phate = phate.PHATE().fit_transform(data)
data_phate = pd.DataFrame(data_phate, index=data.index)
# Out:
# Calculating PHATE...
#   Running PHATE on 13592 observations and 3897 variables.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 7.04 seconds.
#     Calculating KNN search...

# %%
scprep.plot.scatter2d(data_phate, figsize=(8,4), cmap="Spectral",
                      ticks=False, label_prefix="PHATE")
# Out:
#                         CXCL8      CCL2      CCL4    CCL4L2      BCAN  \
# TCGCGAGGTTTAGGAA_1   0.729694  0.083160  3.117084  2.848187 -0.010687
# ACCTTTATCGTGACAT_1   1.184026  0.446326  3.755201  2.975542 -0.025347
# CGGAGCTTCCGCATCT_1   0.895403  0.538668  2.007071  1.930943  0.047721
# CGCTGGAGTCGTTGTA_1   0.664832  0.238538  1.784497  2.519630  0.045499
# GTGTGCGAGCGGCTTC_1   0.075460  0.125846  1.308788  1.750960  0.043040
# ...                       ...       ...       ...       ...       ...
# CTGCCTACAAGCTGAG_12  2.538301  0.525919  3.686919  3.076166  0.020048
# TCGCGAGGTTGCTCCT_12 -0.024903  2.853222  4.139892  4.993707  0.039266
# AGAGCTTTCACCCGAG_12  1.030138  0.093477  4.300857  2.757106  0.037308
# CTCGAAAAGATCGGGT_12  1.766901  0.559936  3.214214  4.358291  0.043802
# CACCAGGCAGTAACGG_12  1.965540  3.215819  4.696405  4.738297  0.029406
#
#                          CCL5      G0S2     PLCG2      IL1B      MT2A  ...  \
# TCGCGAGGTTTAGGAA_1   0.029759  0.095742  0.009434  0.018061  1.327442  ...
# ACCTTTATCGTGACAT_1  -0.413329  1.077078  0.030452 -0.170603  3.205380  ...
# CGGAGCTTCCGCATCT_1   0.176595 -0.046900  0.261152  0.159855  2.531224  ...
# CGCTGGAGTCGTTGTA_1  -0.007649  0.044083 -0.203399 -0.389829  0.545230  ...
# GTGTGCGAGCGGCTTC_1   0.144200  0.013407 -0.066121 -0.183582  1.022912  ...
# ...                       ...       ...       ...       ...       ...  ...
# CTGCCTACAAGCTGAG_12 -0.034412  0.052655 -0.049700  2.264269  1.393748  ...
# TCGCGAGGTTGCTCCT_12 -0.491260 -0.021603  0.030526 -0.245134  1.596136  ...
# AGAGCTTTCACCCGAG_12 -0.968815  0.174377  0.282503  2.962171  1.572853  ...
# CTCGAAAAGATCGGGT_12 -0.750939  0.036249  0.096787 -0.664345  1.440992  ...
# CACCAGGCAGTAACGG_12 -0.069985  0.062970  0.049701 -0.543328  1.481021  ...
#
#                         ZMAT1   RABGAP1    RIMKLB    ZNF772       DBP  \
# TCGCGAGGTTTAGGAA_1   0.223402  0.127013  0.115992 -0.013796  0.074150
# ACCTTTATCGTGACAT_1  -0.108003  0.082367 -0.004478  0.006601 -0.205161
# CGGAGCTTCCGCATCT_1  -0.078162 -0.056885  0.059417 -0.000840  0.004253
# CGCTGGAGTCGTTGTA_1   0.276502  0.069838 -0.014112 -0.005623 -0.054021
# GTGTGCGAGCGGCTTC_1  -0.015611  0.027243  0.042572  0.000559  0.285240
# ...                       ...       ...       ...       ...       ...
# CTGCCTACAAGCTGAG_12  0.309112  0.090654  0.054950  0.002227  0.184709
# TCGCGAGGTTGCTCCT_12  0.136042  0.038589  0.076493  0.000752  0.136464
# AGAGCTTTCACCCGAG_12  0.016915  0.021377  0.023140 -0.001269  0.071605
# CTCGAAAAGATCGGGT_12  0.142225  0.201710 -0.129871  0.001564 -0.018451
# CACCAGGCAGTAACGG_12  0.120937  0.062564 -0.000354  0.001610  0.109696
#
#                      C19orf54    DUSP28      IQCG  ZBTB11-AS1      UGDH
# TCGCGAGGTTTAGGAA_1   0.000543  0.066027  0.108264    0.014820 -0.004421
# ACCTTTATCGTGACAT_1  -0.043939 -0.242078 -0.022291   -0.044276 -0.031445
# CGGAGCTTCCGCATCT_1   0.022567  0.178180 -0.074492    0.001362  0.019029
# CGCTGGAGTCGTTGTA_1   0.001309 -0.027166 -0.104795    0.000076 -0.000890
# GTGTGCGAGCGGCTTC_1   0.002565  0.146575 -0.032208    0.019847 -0.059371
# ...                       ...       ...       ...         ...       ...
# CTGCCTACAAGCTGAG_12  0.003203  0.282798 -0.112089    0.035287 -0.013079
# TCGCGAGGTTGCTCCT_12 -0.008558  0.243793 -0.062706    0.040348 -0.025063
# AGAGCTTTCACCCGAG_12 -0.007166  0.036553  0.085168   -0.034910  0.004850
# CTCGAAAAGATCGGGT_12  0.075284  0.028940 -0.129582    0.001542 -0.331543
# CACCAGGCAGTAACGG_12 -0.005808  2.002001  0.151987    0.038000  0.173882
#
# [13592 rows x 3897 columns]
