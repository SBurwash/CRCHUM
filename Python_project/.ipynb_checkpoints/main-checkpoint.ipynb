# %%
import scprep
import matplotlib as plt

# %%
data_paths = [
    "../data/14_EAE_all_cells.MPS12344479-A02.sorted.1229.merged.10x_outputs/filtered_feature_bc_matrix",
    "../data/15_EAE_all_cells.MPS12344479-B02.sorted.1229.merged.10x_outputs/filtered_feature_bc_matrix",
    "../data/16_WT_all_cells.MPS12344479-H01.sorted.1229.merged.10x_outputs/filtered_feature_bc_matrix"
]

seurat_path = "../../tutorials/seurat_guidedClustering/seurat_clusteringTutorial/filtered_gene_bc_matrices/hg19"

data = scprep.io.load_10X(seurat_path, sparse=True, gene_labels='both')
# T1 = scprep.io.load_10X(data_paths[0], sparse=True, gene_labels='both')
# T2 = scprep.io.load_10X(data_paths[1], sparse=True, gene_labels='both')
# T3 = scprep.io.load_10X(data_paths[2], sparse=True, gene_labels='both')

# # Concatenating data matrices
# data, sample_labels = scprep.utils.combine_batches(
#     data=[T1, T2, T3],
#     batch_labels=["14_EAE", "15_EAE", "16_WT"],
#     append_to_cell_names=True
# )

# del T1, T2, T3

# %%
data = scprep.filter.filter_empty_cells(data)
data = scprep.filter.filter_empty_genes(data)
data.head()
# Out:
#                   AL627309.1 (ENSG00000237683)  AP006222.2 (ENSG00000228463)  \
# 0
# AAACATACAACCAC-1                           0.0                           0.0
# AAACATTGAGCTAC-1                           0.0                           0.0
# AAACATTGATCAGC-1                           0.0                           0.0
# AAACCGTGCTTCCG-1                           0.0                           0.0
# AAACCGTGTATGCG-1                           0.0                           0.0
#
#                   RP11-206L10.2 (ENSG00000228327)  \
# 0
# AAACATACAACCAC-1                              0.0
# AAACATTGAGCTAC-1                              0.0
# AAACATTGATCAGC-1                              0.0
# AAACCGTGCTTCCG-1                              0.0
# AAACCGTGTATGCG-1                              0.0
#
#                   RP11-206L10.9 (ENSG00000237491)  FAM87B (ENSG00000177757)  \
# 0
# AAACATACAACCAC-1                              0.0                       0.0
# ...

# %%
scprep.plot.plot_library_size(data, cutoff=500)
data = scprep.filter.filter_library_size(data, cutoff=500)
plt.pyplot.show()
# Out:
# C:\Users\sburw\AppData\Roaming\Python\Python37\site-packages\scprep\plot\histogram.py:156: MatplotlibDeprecationWarning: The 'linthreshx' parameter of __init__() has been renamed 'linthresh' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   ax.set_xscale("symlog", linthreshx=abs_min)

# %% [markdown]
# # Filter by mithocondrial expression to remove dead cells

# %%
mt_genes = scprep.select.get_gene_set(data, starts_with="MT")
scprep.plot.plot_gene_set_expression(data, genes=mt_genes, percentile=90)
data = scprep.filter.filter_gene_set_expression(data, genes=mt_genes,
                                                percentile=90)

plt.pyplot.show()

# %% [markdown]
# # Library size normalize

# %%
data = scprep.normalize.library_size_normalize(data)

# %% [markdown]
# # Square root transform

# %%
# num = data._get_numeric_data()
# num[num < 0] = 0
data = scprep.transform.sqrt(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-fe436afee2c7> in <module>()
#       1 num = data._get_numeric_data()
# ----> 2 num[num < 0] = 0
#       3 data = scprep.transform.sqrt(data)
#
# C:\Users\sburw\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3030
#    3031         if isinstance(key, DataFrame) or getattr(key, "ndim", None) == 2:
# -> 3032             self._setitem_frame(key, value)
#    3033         elif isinstance(key, (Series, np.ndarray, list, Index)):
#    3034             self._setitem_array(key, value)
#
# C:\Users\sburw\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py in _setitem_frame(self, key, value)
#    3084         self._check_inplace_setting(value)
#    3085         self._check_setitem_copy()
# -> 3086         self._where(-key, value, inplace=True)
#    3087
# ...
